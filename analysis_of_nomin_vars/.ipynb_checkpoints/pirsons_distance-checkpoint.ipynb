# %%
import pandas as pd
import sqlite3
import numpy as np

connection = sqlite3.connect('german_credit.db')
cursor = connection.cursor()

def select(query):
    try:
        return pd.read_sql_query(query, connection)
    except:
        cursor.executescript(query)
        connection.commit()

query = r'''
    SELECT * 
    FROM german_credit
'''
df = select(query).assign(contract_dt = lambda x: x['contract_dt'].astype('datetime64[ns]'))

# %%
df = pd.read_csv('../german_credit_augmented.csv')

# %%
df.head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own             NaN              NaN           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich              NaN            936
# 3   35  female    3     own          little              NaN           1393
# 4   28    male    2     own          little              NaN            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               1000 non-null   int64
#  1   sex               1000 non-null   object
#  2   job               1000 non-null   int64
#  3   housing           1000 non-null   object
#  4   saving_accounts   817 non-null    object
#  5   checking_account  606 non-null    object
#  6   credit_amount     1000 non-null   int64
#  7   duration          1000 non-null   int64
#  8   purpose           1000 non-null   object
#  9   default           1000 non-null   int64
#  10  contract_dt       1000 non-null   object
#  11  client_id         1000 non-null   int64
# dtypes: int64(6), object(6)
# memory usage: 93.9+ KB

# %%
df.to_sql('german_credit', connection, index=False, if_exists='replace')
# Out:
# 1000

# %%
query = r'''
    SELECT *
    FROM german_credit
    LIMIT 5
'''
select(query)
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own            None             None           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich             None            936
# 3   35  female    3     own          little             None           1393
# 4   28    male    2     own          little             None            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %%
query = r'''
    SELECT 
        DISTINCT housing
    FROM german_credit
'''
list_housing = list(select(query)['housing'])
s = []
for x in list_housing:
    s = s + [f'COUNT(CASE WHEN housing = "{x}" THEN 1 END) AS {x}']
s = ',\n'.join(s)

# %%
query = rf'''
    SELECT 
        sex,
        {s}
    FROM german_credit
    GROUP BY sex
'''
select(query)
# Out:
#       sex  own  rent  free
# 0  female  196    95    19
# 1    male  517    84    89

# %%
pd.pivot_table(data = df, index = ['sex'], columns= 'housing', aggfunc = {'client_id': 'count'})
# Out:
#         client_id
# housing      free  own rent
# sex
# female         19  196   95
# male           89  517   84

# %%
# How can we return rows from the first two (not empty) days for each month?
query = r'''
    WITH date_part AS (
    SELECT *, 
        date(contract_dt, 'start of day') AS day,  
        date(contract_dt, 'start of month') AS month,
        DENSE_RANK() OVER w AS rank_date
    FROM german_credit
    WINDOW w AS (PARTITION BY date(contract_dt, 'start of month') ORDER BY date(contract_dt, 'start of day'))
    ORDER BY contract_dt
    )
    SELECT *
    FROM date_part 
    WHERE rank_date IN (1, 2)
    LIMIT 20
'''
select(query)
# Out:
#     age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0    20    male    2     own            None           little           2996
# 1    49  female    2     own          little         moderate           1092
# 2    30  female    3     own          little         moderate           4795
# 3    39  female    1     own            None         moderate            932
# 4    31    male    2     own          little             None           2775
# 5    36    male    2     own          little         moderate            884
# 6    52    male    2     own        moderate             None           2223
# 7    29  female    1    rent          little           little           1659
# 8    64    male    1     own            None             None           3832
# 9    37    male    2    free            None             None           2279
# 10   63    male    3    free            None             None          13756
# 11   31    male    2    rent          little           little           3161
# 12   30    male    2     own          little           little           2121
# 13   24  female    2    rent          little           little           2124
# 14   38  female    2     own            None             None           1240
# 15   74    male    1     own          little             None           3448
# 16   20  female    2     own            rich         moderate           1577
# 17   40  female    2    rent          little         moderate           3001
# 18   23  female    1     own          little           little            976
# 19   23  female    2    rent            None           little           8471
#
#     duration              purpose  default          contract_dt  client_id  \
# 0         24  furniture/equipment        1  2007-05-01 07:17:29        495
# 1         12             radio/TV        0  2007-05-01 08:41:46        288
# 2         36             radio/TV        0  2007-05-01 12:42:45        141
# 3          6            education        0  2007-05-01 20:28:44        215
# 4         18                  car        1  2007-05-01 23:14:02        598
# 5         18                  car        1  2007-05-02 06:22:11        184
# 6         24             radio/TV        0  2007-06-01 04:40:51        773
# 7         24             radio/TV        1  2007-06-01 06:50:39        466
# 8          9            education        0  2007-06-01 11:55:15        629
# 9         12             radio/TV        0  2007-06-01 12:33:25        681
# 10        60                  car        0  2007-06-01 13:18:05        373
# 11        24             business        1  2007-06-02 00:46:37        914
# 12        12                  car        0  2007-06-02 03:46:50        125
# 13        18  furniture/equipment        1  2007-06-02 06:58:10        761
# 14        12             radio/TV        0  2007-07-02 05:34:35        135
# 15         5             business        0  2007-07-03 02:08:34        430
# 16        11  furniture/equipment        0  2007-07-03 09:23:24        167
# 17        18  furniture/equipment        0  2007-07-03 13:27:22        369
# 18        18                  car        1  2007-07-03 15:46:43        751
# 19        18            education        0  2007-07-03 15:59:16        417
#
#            day       month  rank_date
# 0   2007-05-01  2007-05-01          1
# 1   2007-05-01  2007-05-01          1
# 2   2007-05-01  2007-05-01          1
# 3   2007-05-01  2007-05-01          1
# 4   2007-05-01  2007-05-01          1
# 5   2007-05-02  2007-05-01          2
# 6   2007-06-01  2007-06-01          1
# 7   2007-06-01  2007-06-01          1
# 8   2007-06-01  2007-06-01          1
# 9   2007-06-01  2007-06-01          1
# 10  2007-06-01  2007-06-01          1
# 11  2007-06-02  2007-06-01          2
# 12  2007-06-02  2007-06-01          2
# 13  2007-06-02  2007-06-01          2
# 14  2007-07-02  2007-07-01          1
# 15  2007-07-03  2007-07-01          2
# 16  2007-07-03  2007-07-01          2
# 17  2007-07-03  2007-07-01          2
# 18  2007-07-03  2007-07-01          2
# 19  2007-07-03  2007-07-01          2

# %%
query = r'''
    SELECT * 
    FROM german_credit
'''
df = select(query).assign(contract_dt = lambda x: x['contract_dt'].astype('datetime64[ns]'))

# %%
df.head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own            None             None           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich             None            936
# 3   35  female    3     own          little             None           1393
# 4   28    male    2     own          little             None            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %%
# first two days of month (as date)
(
    df
    .assign(rank = lambda x: x['contract_dt'].astype('datetime64[ns]').dt.day)
    .query('rank in [1, 2]')
    .sort_values('contract_dt')
    .head(20)
)
# Out:
#      age     sex  job housing saving_accounts checking_account  credit_amount  \
# 590   20    male    2     own            None           little           2996
# 725   49  female    2     own          little         moderate           1092
# 282   30  female    3     own          little         moderate           4795
# 578   39  female    1     own            None         moderate            932
# 587   31    male    2     own          little             None           2775
# 441   36    male    2     own          little         moderate            884
# 184   52    male    2     own        moderate             None           2223
# 583   29  female    1    rent          little           little           1659
# 563   64    male    1     own            None             None           3832
# 46    37    male    2    free            None             None           2279
# 454   63    male    3    free            None             None          13756
# 65    31    male    2    rent          little           little           3161
# 181   30    male    2     own          little           little           2121
# 726   24  female    2    rent          little           little           2124
# 425   38  female    2     own            None             None           1240
# 581   32    male    2     own        moderate           little           2325
# 718   35  female    2     own            None           little           1381
# 24    62    male    2     own      quite rich             None           1338
# 788   36    male    2    rent          little           little           7297
# 343   25    male    2     own          little             rich           5152
#
#      duration              purpose  default          contract_dt  client_id  \
# 590        24  furniture/equipment        1  2007-05-01 07:17:29        495
# 725        12             radio/TV        0  2007-05-01 08:41:46        288
# 282        36             radio/TV        0  2007-05-01 12:42:45        141
# 578         6            education        0  2007-05-01 20:28:44        215
# 587        18                  car        1  2007-05-01 23:14:02        598
# 441        18                  car        1  2007-05-02 06:22:11        184
# 184        24             radio/TV        0  2007-06-01 04:40:51        773
# 583        24             radio/TV        1  2007-06-01 06:50:39        466
# 563         9            education        0  2007-06-01 11:55:15        629
# 46         12             radio/TV        0  2007-06-01 12:33:25        681
# 454        60                  car        0  2007-06-01 13:18:05        373
# 65         24             business        1  2007-06-02 00:46:37        914
# 181        12                  car        0  2007-06-02 03:46:50        125
# 726        18  furniture/equipment        1  2007-06-02 06:58:10        761
# 425        12             radio/TV        0  2007-07-02 05:34:35        135
# 581        24                  car        0  2007-08-01 03:15:42        740
# 718        24                  car        1  2007-08-01 03:20:11        414
# 24          6  domestic appliances        0  2007-08-01 18:36:24        816
# 788        60             business        1  2007-08-02 15:47:08        973
# 343        24             radio/TV        0  2007-09-01 09:22:02        477
#
#      rank
# 590     1
# 725     1
# 282     1
# 578     1
# 587     1
# 441     2
# 184     1
# 583     1
# 563     1
# 46      1
# 454     1
# 65      2
# 181     2
# 726     2
# 425     2
# 581     1
# 718     1
# 24      1
# 788     2
# 343     1

# %%
# first two not empty days of each month
(
    df
    .sort_values('contract_dt')
    .assign(rank = lambda x: x.groupby(x['contract_dt'].dt.to_period('M'))['contract_dt'].transform(lambda x: x.dt.date.rank(method = 'dense')))
    .query('rank in [1, 2]')
    .head(20)
)
# Out:
#      age     sex  job housing saving_accounts checking_account  credit_amount  \
# 590   20    male    2     own            None           little           2996
# 725   49  female    2     own          little         moderate           1092
# 282   30  female    3     own          little         moderate           4795
# 578   39  female    1     own            None         moderate            932
# 587   31    male    2     own          little             None           2775
# 441   36    male    2     own          little         moderate            884
# 184   52    male    2     own        moderate             None           2223
# 583   29  female    1    rent          little           little           1659
# 563   64    male    1     own            None             None           3832
# 46    37    male    2    free            None             None           2279
# 454   63    male    3    free            None             None          13756
# 65    31    male    2    rent          little           little           3161
# 181   30    male    2     own          little           little           2121
# 726   24  female    2    rent          little           little           2124
# 425   38  female    2     own            None             None           1240
# 139   74    male    1     own          little             None           3448
# 656   20  female    2     own            rich         moderate           1577
# 821   40  female    2    rent          little         moderate           3001
# 660   23  female    1     own          little           little            976
# 344   23  female    2    rent            None           little           8471
#
#      duration              purpose  default         contract_dt  client_id  \
# 590        24  furniture/equipment        1 2007-05-01 07:17:29        495
# 725        12             radio/TV        0 2007-05-01 08:41:46        288
# 282        36             radio/TV        0 2007-05-01 12:42:45        141
# 578         6            education        0 2007-05-01 20:28:44        215
# 587        18                  car        1 2007-05-01 23:14:02        598
# 441        18                  car        1 2007-05-02 06:22:11        184
# 184        24             radio/TV        0 2007-06-01 04:40:51        773
# 583        24             radio/TV        1 2007-06-01 06:50:39        466
# 563         9            education        0 2007-06-01 11:55:15        629
# 46         12             radio/TV        0 2007-06-01 12:33:25        681
# 454        60                  car        0 2007-06-01 13:18:05        373
# 65         24             business        1 2007-06-02 00:46:37        914
# 181        12                  car        0 2007-06-02 03:46:50        125
# 726        18  furniture/equipment        1 2007-06-02 06:58:10        761
# 425        12             radio/TV        0 2007-07-02 05:34:35        135
# 139         5             business        0 2007-07-03 02:08:34        430
# 656        11  furniture/equipment        0 2007-07-03 09:23:24        167
# 821        18  furniture/equipment        0 2007-07-03 13:27:22        369
# 660        18                  car        1 2007-07-03 15:46:43        751
# 344        18            education        0 2007-07-03 15:59:16        417
#
#      rank
# 590   1.0
# 725   1.0
# 282   1.0
# 578   1.0
# 587   1.0
# 441   2.0
# 184   1.0
# 583   1.0
# 563   1.0
# 46    1.0
# 454   1.0
# 65    2.0
# 181   2.0
# 726   2.0
# 425   1.0
# 139   2.0
# 656   2.0
# 821   2.0
# 660   2.0
# 344   2.0

# %%
(
    df
    .sort_values('contract_dt')
    .assign(double_value = lambda x: x.groupby(df['contract_dt'].dt.to_period('M'))['credit_amount'].transform(lambda x: np.sum(x)))
    .head(200)
)
# Out:
#      age     sex  job housing saving_accounts checking_account  credit_amount  \
# 590   20    male    2     own            None           little           2996
# 725   49  female    2     own          little         moderate           1092
# 282   30  female    3     own          little         moderate           4795
# 578   39  female    1     own            None         moderate            932
# 587   31    male    2     own          little             None           2775
# ..   ...     ...  ...     ...             ...              ...            ...
# 257   36    male    2    rent          little           little           2799
# 752   34  female    3     own          little         moderate           1501
# 158   34    male    1     own            None             None           1898
# 731   60    male    2    free          little             None           2032
# 369   46    male    2     own            rich             None           1149
#
#      duration              purpose  default         contract_dt  client_id  \
# 590        24  furniture/equipment        1 2007-05-01 07:17:29        495
# 725        12             radio/TV        0 2007-05-01 08:41:46        288
# 282        36             radio/TV        0 2007-05-01 12:42:45        141
# 578         6            education        0 2007-05-01 20:28:44        215
# 587        18                  car        1 2007-05-01 23:14:02        598
# ..        ...                  ...      ...                 ...        ...
# 257         9                  car        0 2007-07-18 19:32:17        586
# 752         9            education        1 2007-07-18 22:04:00        195
# 158         6             radio/TV        0 2007-07-19 00:24:14        159
# 731        24                  car        0 2007-07-19 02:59:31        541
# 369        18             radio/TV        0 2007-07-19 07:16:01        427
#
#      double_value
# 590        207663
# 725        207663
# 282        207663
# 578        207663
# 587        207663
# ..            ...
# 257        224333
# 752        224333
# 158        224333
# 731        224333
# 369        224333
#
# [200 rows x 13 columns]

# %%
(
    df
    .sort_values('contract_dt')
    .groupby(df['contract_dt'].dt.to_period('M'))
    ['credit_amount'].sum()
)
# Out:
# contract_dt
# 2007-05    207663
# 2007-06    239594
# 2007-07    224333
# 2007-08    178569
# 2007-09    186909
# 2007-10    188534
# 2007-11    300504
# 2007-12    273973
# 2008-01    288080
# 2008-02    211128
# 2008-03    204944
# 2008-04    305409
# 2008-05    263043
# 2008-06    198575
# Freq: M, Name: credit_amount, dtype: int64

# %%
# percent of total credit_amount of each month
(
    df
    .sort_values('contract_dt')
    .assign(month_total = lambda x: x.groupby(x['contract_dt'].dt.to_period('M'))['credit_amount'].transform(lambda x: x.sum()))
    .assign(**{'perc_of_month, %': lambda x: x['credit_amount'] * 100 / x['month_total']})
    .assign(month = lambda x: x['contract_dt'].dt.to_period('M'))
    [['client_id', 'contract_dt', 'month', 'credit_amount', 'month_total', 'perc_of_month, %']]
    
)
# Out:
#      client_id         contract_dt    month  credit_amount  month_total  \
# 590        495 2007-05-01 07:17:29  2007-05           2996       207663
# 725        288 2007-05-01 08:41:46  2007-05           1092       207663
# 282        141 2007-05-01 12:42:45  2007-05           4795       207663
# 578        215 2007-05-01 20:28:44  2007-05            932       207663
# 587        598 2007-05-01 23:14:02  2007-05           2775       207663
# ..         ...                 ...      ...            ...          ...
# 286        928 2008-06-28 11:49:14  2008-06           1867       198575
# 233        196 2008-06-28 12:33:38  2008-06           1382       198575
# 111        520 2008-06-28 14:08:06  2008-06           5507       198575
# 334        105 2008-06-28 23:47:51  2008-06          11938       198575
# 0          210 2008-06-29 18:52:00  2008-06           3074       198575
#
#      perc_of_month, %
# 590          1.442722
# 725          0.525852
# 282          2.309030
# 578          0.448804
# 587          1.336300
# ..                ...
# 286          0.940199
# 233          0.695959
# 111          2.773259
# 334          6.011834
# 0            1.548030
#
# [1000 rows x 6 columns]

# %%
# percent of total credit_amount of each month (SQL)
query = r'''
    SELECT 
        client_id,
        contract_dt,
        date(contract_dt, 'start of month') AS month,
        credit_amount,
        SUM(credit_amount) OVER w AS month_total,
        credit_amount * 100.0 / SUM(credit_amount) OVER w AS perc_of_month
    FROM german_credit
    WINDOW w AS (PARTITION BY date(contract_dt, 'start of month'))
    ORDER BY contract_dt
'''
select(query)
# Out:
#      client_id          contract_dt       month  credit_amount  month_total  \
# 0          495  2007-05-01 07:17:29  2007-05-01           2996       207663
# 1          288  2007-05-01 08:41:46  2007-05-01           1092       207663
# 2          141  2007-05-01 12:42:45  2007-05-01           4795       207663
# 3          215  2007-05-01 20:28:44  2007-05-01            932       207663
# 4          598  2007-05-01 23:14:02  2007-05-01           2775       207663
# ..         ...                  ...         ...            ...          ...
# 995        928  2008-06-28 11:49:14  2008-06-01           1867       198575
# 996        196  2008-06-28 12:33:38  2008-06-01           1382       198575
# 997        520  2008-06-28 14:08:06  2008-06-01           5507       198575
# 998        105  2008-06-28 23:47:51  2008-06-01          11938       198575
# 999        210  2008-06-29 18:52:00  2008-06-01           3074       198575
#
#      perc_of_month
# 0         1.442722
# 1         0.525852
# 2         2.309030
# 3         0.448804
# 4         1.336300
# ..             ...
# 995       0.940199
# 996       0.695959
# 997       2.773259
# 998       6.011834
# 999       1.548030
#
# [1000 rows x 6 columns]

# %%
# rollmean (current row and 2 preceding) in 2007-06) SQLITE
query = r'''
    SELECT 
        contract_dt,
        strftime('%Y-%m', contract_dt) AS month,
        credit_amount,
        ROUND(AVG(credit_amount) OVER w, 2) AS rollmean
    FROM german_credit
    WHERE date(contract_dt, 'start of month') = '2007-06-01'
    WINDOW w AS (
        PARTITION BY date(contract_dt, 'start of month')
        ORDER BY contract_dt
        ROWS BETWEEN 2 preceding AND current row
     )
     ORDER BY contract_dt
     
'''
select(query)
# Out:
#             contract_dt    month  credit_amount  rollmean
# 0   2007-06-01 04:40:51  2007-06           2223   2223.00
# 1   2007-06-01 06:50:39  2007-06           1659   1941.00
# 2   2007-06-01 11:55:15  2007-06           3832   2571.33
# 3   2007-06-01 12:33:25  2007-06           2279   2590.00
# 4   2007-06-01 13:18:05  2007-06          13756   6622.33
# ..                  ...      ...            ...       ...
# 69  2007-06-30 13:04:06  2007-06           2101   1975.00
# 70  2007-06-30 16:22:32  2007-06           3378   2585.67
# 71  2007-06-30 20:03:08  2007-06           3972   3150.33
# 72  2007-06-30 23:13:06  2007-06           6314   4554.67
# 73  2007-06-30 23:56:46  2007-06           3949   4745.00
#
# [74 rows x 4 columns]

# %%
# rollmean (current row and 2 preceding) in 2007-06) PANDAS
(
    df
    .sort_values('contract_dt')
    .assign(month = lambda x: x['contract_dt'].dt.to_period('M'),
           rollmean = lambda x: x.groupby(x['contract_dt'].dt.to_period('M'))['credit_amount']
            .transform(lambda x: x.rolling(3, min_periods = 1).mean().round(2))
           )
    .query('month.astype("str") == "2007-06"')
)[['contract_dt', 'month', 'credit_amount', 'rollmean']]
# Out:
#             contract_dt    month  credit_amount  rollmean
# 184 2007-06-01 04:40:51  2007-06           2223   2223.00
# 583 2007-06-01 06:50:39  2007-06           1659   1941.00
# 563 2007-06-01 11:55:15  2007-06           3832   2571.33
# 46  2007-06-01 12:33:25  2007-06           2279   2590.00
# 454 2007-06-01 13:18:05  2007-06          13756   6622.33
# ..                  ...      ...            ...       ...
# 366 2007-06-30 13:04:06  2007-06           2101   1975.00
# 561 2007-06-30 16:22:32  2007-06           3378   2585.67
# 226 2007-06-30 20:03:08  2007-06           3972   3150.33
# 564 2007-06-30 23:13:06  2007-06           6314   4554.67
# 600 2007-06-30 23:56:46  2007-06           3949   4745.00
#
# [74 rows x 4 columns]
